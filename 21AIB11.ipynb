# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('california_housing_test.csv',nrows=500)
df.head(500)
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.05     37.37                27.0       3885.0           661.0
# 1      -118.30     34.26                43.0       1510.0           310.0
# 2      -117.81     33.78                27.0       3589.0           507.0
# 3      -118.36     33.82                28.0         67.0            15.0
# 4      -119.67     36.33                19.0       1241.0           244.0
# ..         ...       ...                 ...          ...             ...
# 495    -122.29     37.82                 2.0        158.0            43.0
# 496    -116.31     33.65                 8.0       3079.0           558.0
# 497    -118.27     34.01                43.0       1235.0           385.0
# 498    -122.44     37.76                52.0       1968.0           472.0
# 499    -118.27     34.15                14.0       1744.0           536.0
#
#      population  households  median_income  median_house_value
# ...

# %%
x=df.longitude
plt.plot(x)

# %%
y=df.latitude
plt.bar(x,y)
# Out:
# <BarContainer object of 500 artists>

# %%
plt.scatter(x,y)

# %%
plt.hist(x)
# Out:
# (array([  5.,  40., 106.,  34.,  24.,  32., 180.,  72.,   6.,   1.]),
#  array([-124.16 , -123.242, -122.324, -121.406, -120.488, -119.57 ,
#         -118.652, -117.734, -116.816, -115.898, -114.98 ]),
#  <a list of 10 Patch objects>)

# %%
plt.pie(x,labels=y)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f57a0c4e690>,
# ...
#  [Text(1.08645552482841, -0.17208832781401595, '37.37'),
#   Text(0.33988860380931407, -1.0461719442809367, '34.26'),
#   Text(-0.0345855658946219, -1.0994561558478577, '33.78'),
#   Text(-0.5894326256864775, -0.9287460254430945, '33.82'),
#   Text(-0.6742160916176109, -0.8691562930819022, '36.33'),
#   Text(1.0805175566860032, 0.20611115858514242, '36.51'),
#   Text(-1.0735086681884392, -0.23995653632331768, '38.63'),
#   Text(-1.0994569844944695, 0.03455921362427102, '35.48'),
#   Text(7.259809478984105e-13, -1.1, '38.4'),
#   Text(-0.4683791681571375, 0.9952994297378193, '34.08'),
#   Text(0.40489680495722086, 1.0227700510551894, '33.98'),
#   Text(-1.0978268179384176, -0.06911062013329398, '35.85'),
#   Text(1.0951210388244716, -0.10348869660020973, '37.25'),
#   Text(-1.0994561558478546, -0.0345855658947257, '32.97'),
#   Text(1.0994561558478337, 0.03458556589538622, '33.73'),
# ...

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f57a0d34190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f57a02fa0d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f57a0c39510>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f57a03dbbd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f57a03db190>],
#  'means': []}
